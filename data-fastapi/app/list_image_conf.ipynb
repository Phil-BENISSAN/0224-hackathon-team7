# %%
import pandas as pd

# %%
image_conf= [
  {
    "url": "https://as1.ftcdn.net/v2/jpg/04/45/85/96/1000_F_445859661_zQCAaA0NzUVdBKQqIc0WKxRjqlDINHXS.jpg"
  },
  {
    "url": "https://as1.ftcdn.net/v2/jpg/05/90/46/46/1000_F_590464626_5iF5Y9jag0ApGdqJALU8zsZx9RpRzvOj.jpg"
  },
  {
    "url": "https://img.freepik.com/photos-premium/groupe-personnes-gare_1048944-17099247.jpg?w=740"
  },
  {
    "url": "https://img.freepik.com/vecteurs-libre/gens-multiculturels-debout-ensemble_74855-6583.jpg?ga=GA1.1.889898203.1716293056&semt=sph"
  },
  {
    "url": "https://img.freepik.com/photos-gratuite/gros-plan-diverses-personnes-joignant-leurs-mains_53876-96081.jpg?t=st=1720134593~exp=1720138193~hmac=c20aa882997b6ac27d987a42e301f9d37cddc3423ad021b3f68e7aa0f2296b96&w=900"
  },
  {
    "url": "https://img.freepik.com/photos-premium/public-salle-conference_488220-10757.jpg?w=740"
  },
  {
    "url": "data:image/jpeg;base64,..."
  },
  {
    "url": "data:image/jpeg;base64,..."
  },
  {
    "url": "https://www.wechamp-entreprise.co/wp-content/uploads/2020/10/Compe%CC%81tences-animateur.jpg.webp"
  },
  {
    "url": "https://static.s-sfr.fr/media/securite_travail_collaboratif_0.jpg"
  },
  {
    "url": "https://sf1.topsante.com/wp-content/uploads/topsante/2023/09/3-conseils-pour-adopter-bienveillance.jpg"
  },
  {
    "url": "data:image/jpeg;base64,..."
  },
  {
    "url": "data:image/jpeg;base64,..."
  },
  {
    "url": "https://img.freepik.com/premium-photo/business-people-enjoying-conference-happy-hour_662214-335863.jpg"
  },
  {
    "url": "https://s3.envato.com/files/276430199/179_179_T13A1094.jpg"
  },
  {
    "url": "https://media.istockphoto.com/id/1141462781/photo/nothing-keeps-employees-inspired-like-good-news.jpg?s=612x612&w=0&k=20&c=350orpdaUHKMasakc6eKcFcR5XthrsEFdIuD8vzXsxQ="
  },
  {
    "url": "https://static.wixstatic.com/media/e44cd8_c616317e13b44738bb52d63593f5c168~mv2.png/v1/fill/w_640,h_360,al_c,q_85,usm_0.66_1.00_0.01,enc_auto/e44cd8_c616317e13b44738bb52d63593f5c168~mv2.png"
  },
  {
    "url": "https://img.freepik.com/photos-gratuite/vue-arriere-femme-tenant-reunion-au-travail-collegues_23-2148908799.jpg?t=st=1720135441~exp=1720139041~hmac=aa813cdc806b38c3809fb830b59f120e66727b93f91060b0af719f6ec4d5433d&w=740"
  },
  {
    "url": "https://centdegres.ca/uploads/article/conferences_100d.jpg"
  },
  {
    "url": "https://img.freepik.com/photos-premium/jeunes-gens-affaires-reunion-tableau-blanc-groupe-travail-equipe-bureau_772720-4675.jpg"
  }
]

# %%
len(image_conf)
# Out:
# 20

# %%
# image_conf_1 = [{'url' : 'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/bureau.png'},
#  {'url' :'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/conference.png'},
#  {'url' :'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/handicap.png'},
#  {'url' :'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/herosection4-img.jpg'},
#  {'url' :'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/lgbt.jpg'},
#  {'url' :'https://github.com/Phil-BENISSAN/0224-hackathon-team7/blob/main/data-fastapi/app/image_conf/signes.png'}]

# %%
image_conf_2 = [{'url' :'https://www.untangle.com/website/wp-content/uploads/blogs/smbs-benefit-from-sd-wan-features-blog-pic-02.jpg'},
 {'url' :'https://assets.ey.com/content/dam/ey-sites/ey-com/en_be/topics/diversity/ey-inclusive-society-where-different-abilities-are-valued.jpg.rendition.1800.1200.jpg'},
 {'url' :'https://stellarmenus.com/wp-content/uploads/2023/09/getty-images-XCA8LD0E7AI-unsplash.webp'},
 {'url' :'https://achievalife.com/wp-content/uploads/2021/11/120121_blog_PersonsWDisabilities-e1638451893837.jpg'},
 {'url' :'https://conservationbytes.com/wp-content/uploads/2018/07/diverse-group.jpg?w=300'},
 {'url' :'https://i0.wp.com/talenty.fr/wp-content/uploads/2023/05/Limportance-de-la-diversite-et-de-linclusion-en-entreprise-Creer-un-environnement-inclusif-pour-les-salarie.e.s-et-les-entrepreneur.e.s.png?w=1120&ssl=1'}]

# %%
list_image_conf = image_conf + image_conf_2

# %%
import json
list_image_conf = json.dumps(list_image_conf)

# %%
list_image_conf = json.loads(list_image_conf)

# %%
list_image_conf = pd.DataFrame(list_image_conf)

# %%
list_image_conf.to_json("list_image_conf.json", orient="records", force_ascii=False)
